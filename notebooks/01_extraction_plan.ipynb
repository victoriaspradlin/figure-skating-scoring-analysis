# %%
# Figure Skating Scoring Analysis — Data Extraction (v1)

**Discipline:** Women  
**Event:** World Championships  
**Season:** 2023–2024


"""
Extract TES, PCS, and placement data from official ISU protocols 
and produce a clean CSV suitable for analysis.
"""

# %%
# Target Dataset Schema (v1)

"""
Each row represents one skater in one segment.

Columns:
- season
- event
- discipline
- segment (SP / FS)
- skater
- nation
- TES
- PCS
- SS
- TR
- PE
- CO
- IN
- total_score
- rank
"""

# %%
import pandas as pd
import numpy as np

# %%
data = [
    {
        "season": "2023-2024",
        "event": "World Championships",
        "discipline": "Women",
        "segment": "SP",
        "skater": "Example Skater 1",
        "nation": "JPN",
        "TES": 38.45,
        "PCS": 34.12,
        "SS": 8.50,
        "TR": 8.45,
        "PE": 8.60,
        "CO": 8.57,
        "IN": 8.00,
        "total_score": 72.57,
        "rank": 1
    },
    {
        "season": "2023-2024",
        "event": "World Championships",
        "discipline": "Women",
        "segment": "SP",
        "skater": "Example Skater 2",
        "nation": "USA",
        "TES": 35.10,
        "PCS": 32.80,
        "SS": 8.10,
        "TR": 8.05,
        "PE": 8.20,
        "CO": 8.30,
        "IN": 8.15,
        "total_score": 67.90,
        "rank": 2
    }
]

df = pd.DataFrame(data)
df

# %%
df.info()
df.describe()

# %%
df.to_csv("data/raw/womens_worlds_2024_sp_raw.csv", index=False)
